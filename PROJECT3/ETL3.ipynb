# %%
import pandas as pd
import numpy as np

df= pd.read_csv('data3.csv')

print(df.head())
print(df.info())
# Out:
#   user_id  watch_date video_id watch_time_minutes        country video_genre  \
# 0    1001  2023-11-01     V001                120            USA      Action
# 1    1002  11/02/2023     V002            45 mins             UK      Comedy
# 2    1003  Nov 3 2023     V003                 90  United States      Sci-Fi
# 3   U1004  2023-11-04     V001                 60            USA      Action
# 4    1005  2023/11/05     V004                 30         Canada      Comedy
#
#    user_rating
# 0          4.5
# 1          NaN
# 2          5.0
# 3          NaN
# 4          3.5
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             25 non-null     str
#  1   watch_date          23 non-null     str
#  2   video_id            25 non-null     str
#  3   watch_time_minutes  24 non-null     str
# ...
